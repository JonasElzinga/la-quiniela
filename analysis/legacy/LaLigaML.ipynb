# %%
import pandas as pd
import sqlite3
import numpy as np
import calendar

# %%
# create a connection with the given database
con = sqlite3.connect("../laliga.sqlite")

# read the two tables from the database into Pandas DataFrames
df_matches = pd.read_sql_query("SELECT * from Matches", con)
df_predictions = pd.read_sql_query("SELECT * from Predictions", con)

# close the connection of the database
con.close()

# %%
df_predictions
# Out:
#        season  division  matchday     date      time        home_team  \
# 0   2021-2022         1         3  8/27/21   8:00 PM     RCD Mallorca
# 1   2021-2022         1         3  8/27/21  10:15 PM         Valencia
# 2   2021-2022         1         3  8/28/21   5:00 PM    Celta de Vigo
# 3   2021-2022         1         3  8/28/21   7:30 PM    Real Sociedad
# 4   2021-2022         1         3  8/28/21   7:30 PM         Elche CF
# 5   2021-2022         1         3  8/28/21  10:00 PM       Real Betis
# 6   2021-2022         1         3  8/29/21   5:00 PM        Barcelona
# 7   2021-2022         1         3  8/29/21   7:30 PM         Cádiz CF
# 8   2021-2022         1         3  8/29/21   7:30 PM   Rayo Vallecano
# 9   2021-2022         1         3  8/29/21  10:00 PM  Atlético Madrid
# 10  2021-2022         1         3  8/27/21   8:00 PM     RCD Mallorca
# 11  2021-2022         1         3  8/27/21  10:15 PM         Valencia
# 12  2021-2022         1         3  8/28/21   5:00 PM    Celta de Vigo
# 13  2021-2022         1         3  8/28/21   7:30 PM    Real Sociedad
# 14  2021-2022         1         3  8/28/21   7:30 PM         Elche CF
# 15  2021-2022         1         3  8/28/21  10:00 PM       Real Betis
# 16  2021-2022         1         3  8/29/21   5:00 PM        Barcelona
# 17  2021-2022         1         3  8/29/21   7:30 PM         Cádiz CF
# 18  2021-2022         1         3  8/29/21   7:30 PM   Rayo Vallecano
# 19  2021-2022         1         3  8/29/21  10:00 PM  Atlético Madrid
# 20  2021-2022         1         3  8/27/21   8:00 PM     RCD Mallorca
# 21  2021-2022         1         3  8/27/21  10:15 PM         Valencia
# 22  2021-2022         1         3  8/28/21   5:00 PM    Celta de Vigo
# 23  2021-2022         1         3  8/28/21   7:30 PM    Real Sociedad
# 24  2021-2022         1         3  8/28/21   7:30 PM         Elche CF
# 25  2021-2022         1         3  8/28/21  10:00 PM       Real Betis
# 26  2021-2022         1         3  8/29/21   5:00 PM        Barcelona
# 27  2021-2022         1         3  8/29/21   7:30 PM         Cádiz CF
# 28  2021-2022         1         3  8/29/21   7:30 PM   Rayo Vallecano
# 29  2021-2022         1         3  8/29/21  10:00 PM  Atlético Madrid
#
#       away_team score pred
# 0      Espanyol   1:0    X
# 1        Alavés   3:0    X
# 2      Athletic   0:1    X
# 3       Levante   1:0    X
# 4    Sevilla FC   1:1    X
# 5   Real Madrid   0:1    X
# 6        Getafe   2:1    X
# 7    CA Osasuna   2:3    X
# 8    Granada CF   4:0    X
# 9    Villarreal   2:2    X
# 10     Espanyol   1:0    X
# 11       Alavés   3:0    X
# 12     Athletic   0:1    X
# 13      Levante   1:0    X
# 14   Sevilla FC   1:1    X
# 15  Real Madrid   0:1    X
# 16       Getafe   2:1    X
# 17   CA Osasuna   2:3    X
# 18   Granada CF   4:0    X
# 19   Villarreal   2:2    X
# 20     Espanyol   1:0    X
# 21       Alavés   3:0    X
# 22     Athletic   0:1    X
# 23      Levante   1:0    X
# 24   Sevilla FC   1:1    X
# 25  Real Madrid   0:1    X
# 26       Getafe   2:1    X
# 27   CA Osasuna   2:3    X
# 28   Granada CF   4:0    X
# 29   Villarreal   2:2    X

# %%
# function change the 2 digit representation of the year in the "date" column to a 4 digit representation
def get_year(season, date):
    # get only the 2 digit year part of the date
    year = date.split("/")[-1]
    
    # split the years of the season into two separate years
    season_years = season.split("-")
    
    # check if the 2 digit year part of the date are equal to the last part of the start year or the end year of the season
    for season_year in season_years:
        # if the 2 digit part is equal to the last part of one of the season years
        if year == season_year[2:4]:
            # return the complete date, now containing a 4 digit year representation
            return f"{date.split("/")[0]}/{date.split("/")[1]}/{season_year}"

# %%
# creating two new columns, one for the score of the home team, and one for the score of the away team
df_matches[['home_score', 'away_score']] = df_matches['score'].str.split(':', expand=True).astype(float)

# creating one new column to show which team won (1 for home team, 2 for away team), or if it was a tie (X)
df_matches['winner'] = df_matches.apply(lambda row: 
                                        np.nan if pd.isna(row['home_score']) or pd.isna(row['away_score'])
                                        else 1 if row['home_score'] > row['away_score']
                                        else 2 if row['home_score'] < row['away_score']
                                        else 0, axis=1)

# improve the "date" column using the "get_year" function to change the year from 2 digits to the correct 4 digits
df_matches['date'] = df_matches.apply(lambda row: get_year(row['season'], row['date']), axis=1)


# change the "date" column to datetime
df_matches['date'] = pd.to_datetime(df_matches['date'], format='mixed')


# add a weekday column to store which day of the week the match was played
df_matches['weekday'] = df_matches.apply(lambda row: row['date'].weekday(), axis=1)

df_matches = df_matches.drop(columns=['time'])

df_matches = df_matches.dropna()
df_matches
# Out:
#           season  division  matchday       date        home_team  \
# 0      1928-1929         1         1 1929-02-10      Arenas Club
# 1      1928-1929         1         1 1929-02-10         Espanyol
# 2      1928-1929         1         1 1929-02-10      Real Madrid
# 3      1928-1929         1         1 1929-02-10         Donostia
# 4      1928-1929         1         1 1929-02-12           Racing
# ...          ...       ...       ...        ...              ...
# 48345  2021-2022         2         3 2021-08-28     Ponferradina
# 48346  2021-2022         2         3 2021-08-29    SD Amorebieta
# 48347  2021-2022         2         3 2021-08-29          CD Lugo
# 48348  2021-2022         2         3 2021-08-29  Real Sociedad B
# 48349  2021-2022         2         3 2021-08-29        Burgos CF
#
#              away_team score  home_score  away_score  winner  weekday
# 0      Athletic Madrid   2:3         2.0         3.0     2.0        6
# 1           Real Unión   3:2         3.0         2.0     1.0        6
# 2            Catalunya   5:0         5.0         0.0     1.0        6
# 3             Athletic   1:1         1.0         1.0     0.0        6
# 4            Barcelona   0:2         0.0         2.0     2.0        1
# ...                ...   ...         ...         ...     ...      ...
# 48345           Girona   2:1         2.0         1.0     1.0        5
# 48346       UD Almería   2:1         2.0         1.0     1.0        6
# 48347  Real Valladolid   0:2         0.0         2.0     2.0        6
# 48348   CF Fuenlabrada   0:0         0.0         0.0     0.0        6
# 48349         SD Eibar   0:1         0.0         1.0     2.0        6
#
# [48000 rows x 11 columns]

# %%
df_matches.count()
# Out:
# season        48000
# division      48000
# matchday      48000
# date          48000
# home_team     48000
# away_team     48000
# score         48000
# home_score    48000
# away_score    48000
# winner        48000
# weekday       48000
# dtype: int64

# %%
df_matches.dtypes
# Out:
# season                object
# division               int64
# matchday               int64
# date          datetime64[ns]
# home_team             object
# away_team             object
# score                 object
# home_score           float64
# away_score           float64
# winner               float64
# weekday                int64
# dtype: object

# %%
df_matches.corr(numeric_only=True).style.background_gradient("coolwarm", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_9722d_row0_col0, #T_9722d_row1_col1, #T_9722d_row2_col2, #T_9722d_row3_col3, #T_9722d_row4_col4, #T_9722d_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9722d_row0_col1, #T_9722d_row1_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_9722d_row0_col2, #T_9722d_row2_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9722d_row0_col3, #T_9722d_row3_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_9722d_row0_col4, #T_9722d_row4_col0 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_9722d_row0_col5, #T_9722d_row1_col4, #T_9722d_row4_col1, #T_9722d_row5_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_9722d_row1_col2, #T_9722d_row2_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_9722d_row1_col3, #T_9722d_row3_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_9722d_row1_col5, #T_9722d_row5_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_9722d_row2_col3, #T_9722d_row3_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9722d_row2_col4, #T_9722d_row4_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_9722d_row2_col5, #T_9722d_row5_col2 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_9722d_row3_col4, #T_9722d_row4_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_9722d_row3_col5, #T_9722d_row4_col5, #T_9722d_row5_col3, #T_9722d_row5_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# </style>
# <table id="T_9722d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9722d_level0_col0" class="col_heading level0 col0" >division</th>
#       <th id="T_9722d_level0_col1" class="col_heading level0 col1" >matchday</th>
#       <th id="T_9722d_level0_col2" class="col_heading level0 col2" >home_score</th>
#       <th id="T_9722d_level0_col3" class="col_heading level0 col3" >away_score</th>
#       <th id="T_9722d_level0_col4" class="col_heading level0 col4" >winner</th>
#       <th id="T_9722d_level0_col5" class="col_heading level0 col5" >weekday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9722d_level0_row0" class="row_heading level0 row0" >division</th>
#       <td id="T_9722d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9722d_row0_col1" class="data row0 col1" >0.090943</td>
#       <td id="T_9722d_row0_col2" class="data row0 col2" >-0.089428</td>
#       <td id="T_9722d_row0_col3" class="data row0 col3" >-0.047485</td>
#       <td id="T_9722d_row0_col4" class="data row0 col4" >-0.021553</td>
#       <td id="T_9722d_row0_col5" class="data row0 col5" >0.010434</td>
#     </tr>
#     <tr>
#       <th id="T_9722d_level0_row1" class="row_heading level0 row1" >matchday</th>
#       <td id="T_9722d_row1_col0" class="data row1 col0" >0.090943</td>
#       <td id="T_9722d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9722d_row1_col2" class="data row1 col2" >-0.055361</td>
#       <td id="T_9722d_row1_col3" class="data row1 col3" >-0.007378</td>
#       <td id="T_9722d_row1_col4" class="data row1 col4" >0.009374</td>
#       <td id="T_9722d_row1_col5" class="data row1 col5" >-0.036487</td>
#     </tr>
#     <tr>
#       <th id="T_9722d_level0_row2" class="row_heading level0 row2" >home_score</th>
#       <td id="T_9722d_row2_col0" class="data row2 col0" >-0.089428</td>
#       <td id="T_9722d_row2_col1" class="data row2 col1" >-0.055361</td>
#       <td id="T_9722d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9722d_row2_col3" class="data row2 col3" >0.028580</td>
#       <td id="T_9722d_row2_col4" class="data row2 col4" >-0.040034</td>
#       <td id="T_9722d_row2_col5" class="data row2 col5" >0.048915</td>
#     </tr>
#     <tr>
#       <th id="T_9722d_level0_row3" class="row_heading level0 row3" >away_score</th>
#       <td id="T_9722d_row3_col0" class="data row3 col0" >-0.047485</td>
#       <td id="T_9722d_row3_col1" class="data row3 col1" >-0.007378</td>
#       <td id="T_9722d_row3_col2" class="data row3 col2" >0.028580</td>
#       <td id="T_9722d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_9722d_row3_col4" class="data row3 col4" >0.382256</td>
#       <td id="T_9722d_row3_col5" class="data row3 col5" >-0.008787</td>
#     </tr>
#     <tr>
#       <th id="T_9722d_level0_row4" class="row_heading level0 row4" >winner</th>
#       <td id="T_9722d_row4_col0" class="data row4 col0" >-0.021553</td>
#       <td id="T_9722d_row4_col1" class="data row4 col1" >0.009374</td>
#       <td id="T_9722d_row4_col2" class="data row4 col2" >-0.040034</td>
#       <td id="T_9722d_row4_col3" class="data row4 col3" >0.382256</td>
#       <td id="T_9722d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_9722d_row4_col5" class="data row4 col5" >-0.009148</td>
#     </tr>
#     <tr>
#       <th id="T_9722d_level0_row5" class="row_heading level0 row5" >weekday</th>
#       <td id="T_9722d_row5_col0" class="data row5 col0" >0.010434</td>
#       <td id="T_9722d_row5_col1" class="data row5 col1" >-0.036487</td>
#       <td id="T_9722d_row5_col2" class="data row5 col2" >0.048915</td>
#       <td id="T_9722d_row5_col3" class="data row5 col3" >-0.008787</td>
#       <td id="T_9722d_row5_col4" class="data row5 col4" >-0.009148</td>
#       <td id="T_9722d_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
target = 'winner'
features = ['home_score', 'away_score', 'weekday', 'matchday']
X, y = df_matches[features], df_matches[target]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (38400, 4)
# X_test shape: (9600, 4)
# y_train shape: (38400,)
# y_test shape: (9600,)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_model.coef_, linear_model.intercept_
# Out:
# (array([-0.02366033,  0.24906644, -0.0032003 ,  0.00048266]),
#  np.float64(0.7625963236661013))

# %%
linear_y_pred = linear_model.predict(X_test)

results_df = X_test.copy()
results_df["y_real"] = y_test
results_df["y_pred"] = linear_y_pred.astype(int)
results_df["err"] = results_df["y_real"] - results_df["y_pred"]
results_df["%_err"] = results_df["err"] / results_df["y_real"] * 100
results_df
# Out:
#        home_score  away_score  weekday  matchday  y_real  y_pred  err  %_err
# 23629         3.0         1.0        5        10     1.0       0  1.0  100.0
# 43458         2.0         1.0        6        13     1.0       0  1.0  100.0
# 45365         1.0         1.0        5        19     0.0       0  0.0    NaN
# 19839         1.0         0.0        2        11     1.0       0  1.0  100.0
# 10859         1.0         3.0        6         6     2.0       1  1.0   50.0
# ...           ...         ...      ...       ...     ...     ...  ...    ...
# 27942         3.0         0.0        6        23     1.0       0  1.0  100.0
# 39450         1.0         1.0        6        27     0.0       0  0.0    NaN
# 35036         2.0         0.0        6         9     1.0       0  1.0  100.0
# 42373         4.0         1.0        5        41     1.0       0  1.0  100.0
# 31020         3.0         0.0        6        29     1.0       0  1.0  100.0
#
# [9600 rows x 8 columns]

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

print(f"RMSE: {mean_squared_error(y_test, linear_y_pred)**0.5}")
print(f"MAPE: {mean_absolute_percentage_error(y_test, linear_y_pred)}")
print(f"R^2: {r2_score(y_test, linear_y_pred)}")
# Out:
# RMSE: 0.6317410221199726
# MAPE: 1097436808176832.0
# R^2: 0.1618302293491336
